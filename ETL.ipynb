# %% [markdown]
# Aggiunta colonna 'Country'

# %%
import pandas as pd

# %%
# Leggi il file CSV
df = pd.read_csv('Datasets/atp_tennis.csv')

# Crea la nuova colonna 'Country' dopo 'Tournament'
# Prima otteniamo l'indice della colonna 'Tournament'
tournament_idx = df.columns.get_loc('Tournament')

# Inserisci la nuova colonna 'Country' dopo 'Tournament'
df.insert(tournament_idx + 1, 'Country', '')  # Per ora la riempiamo con valori vuoti

# Salva il dataframe modificato
df.to_csv('atp_tennis.csv', index=False)

# Visualizza le prime righe per verificare
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_58127/2805060484.py in ?()
#       5 # Prima otteniamo l'indice della colonna 'Tournament'
#       6 tournament_idx = df.columns.get_loc('Tournament')
#       7
#       8 # Inserisci la nuova colonna 'Country' dopo 'Tournament'
# ----> 9 df.insert(tournament_idx + 1, 'Country', '')  # Per ora la riempiamo con valori vuoti
#      10
#      11 # Salva il dataframe modificato
#      12 df.to_csv('atp_tennis.csv', index=False)
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
# ...

# %%
# Inserisci 'Australia' dove Tournament è 'Australian Hardcourt Championships'
df.loc[df['Tournament'] == 'Australian Hardcourt Championships', 'Country'] = 'Australia'
df.loc[df['Tournament'] == 'Gold Flake Open', 'Country'] = 'India'
df.loc[df['Tournament'] == 'Australian Open', 'Country'] = 'Australia'
df.loc[df['Tournament'] == 'Marseille Open', 'Country'] = 'France'
df.loc[df['Tournament'] == 'Qatar Open', 'Country'] = 'Qatar'
df.loc[df['Tournament'] == 'Rotterdam Open', 'Country'] = 'Netherlands'
df.loc[df['Tournament'] == 'Dubai Tennis Championships', 'Country'] = 'UAE'
df.loc[df['Tournament'] == 'Indian Wells Masters', 'Country'] = 'USA'
df.loc[df['Tournament'] == 'Miami Open', 'Country'] = 'USA'
df.loc[df['Tournament'] == 'Monte Carlo Masters', 'Country'] = 'Monaco'
df.loc[df['Tournament'] == 'Madrid Open', 'Country'] = 'Spain'
df.loc[df['Tournament'] == 'Rome Masters', 'Country'] = 'Italy'
df.loc[df['Tournament'] == 'Canada Masters', 'Country'] = 'Canada'
df.loc[df['Tournament'] == 'Cincinnati Masters', 'Country'] = 'USA'
df.loc[df['Tournament'] == 'US Open', 'Country'] = 'USA'
df.loc[df['Tournament'] == 'Paris Masters', 'Country'] = 'France'
df.loc[df['Tournament'] == 'Vienna Open', 'Country'] = 'Austria'
df.loc[df['Tournament'] == 'VTB Kremlin Cup', 'Country'] = 'Russia'
df.loc[df['Tournament'] == 'Erste Bank Open', 'Country'] = 'Austria'
df.loc[df['Tournament'] == 'Swiss Indoors Basel', 'Country'] = 'Switzerland'
df.loc[df['Tournament'] == 'Heineken Open', 'Country'] = 'New Zealand'


# Salva il dataframe modificato
df.to_csv('atp_tennis.csv', index=False)

# %%
# Stampa il numero totale di tornei
numero_tornei = df['Tournament'].nunique()
print(f"Numero totale di tornei: {numero_tornei}")
# Out:
# Numero totale di tornei: 265

# %%
# Dizionario delle corrispondenze torneo-paese
tournament_country = {
    'Australian Hardcourt Championships': 'Australia',
    'Gold Flake Open': 'India',
    'Australian Open': 'Australia',
    'Marseille Open': 'France',
    'Qatar Open': 'Qatar',
    'Rotterdam Open': 'Netherlands',
    'Dubai Tennis Championships': 'UAE',
    'Indian Wells Masters': 'United States of America',
    'Miami Open': 'United States of America',
    'Monte Carlo Masters': 'Monaco',
    'Madrid Open': 'Spain',
    'Rome Masters': 'Italy',
    'Canada Masters': 'Canada',
    'Cincinnati Masters': 'United States of America',
    'US Open': 'United States of America',
    'Paris Masters': 'France',
    'Vienna Open': 'Austria',
    'VTB Kremlin Cup': 'Russia',
    'Erste Bank Open': 'Austria',
    'Swiss Indoors Basel': 'Switzerland',
    'Heineken Open': 'New Zealand',
    'French Open': 'France',
    'Wimbledon': 'UK',
    'ATP Finals': 'UK',
    'Hamburg European Open': 'Germany',
    'Stockholm Open': 'Sweden',
    'Barcelona Open': 'Spain',
    'Lyon Open': 'France',
    'Geneva Open': 'Switzerland',
    'Stuttgart Open': 'Germany',
    'Halle Open': 'Germany',
    'Queens Club Championships': 'UK',
    'Eastbourne International': 'UK',
    'Washington Open': 'United States of America',
    'Atlanta Open': 'United States of America',
    'Los Cabos Open': 'Mexico',
    'Mexican Open': 'Mexico',
    'Rio Open': 'Brazil',
    'Chile Open': 'Chile',
    'Buenos Aires Open': 'Argentina',
    'Sofia Open': 'Bulgaria',
    'St. Petersburg Open': 'Russia',
    'Metz Open': 'France',
    'Moselle Open': 'France',
    'Antwerp Open': 'Belgium',
    'Delray Beach Open': 'United States of America',
    'Auckland Open': 'New Zealand',
    'Adelaide International': 'Australia',
    'Brisbane International': 'Australia',
    'Sydney International': 'Australia',
    'Croatia Open': 'Croatia',
    'Australian Hardcourt Championships': 'Australia',
    'Hopman Cup': 'Australia',
    'Next Gen ATP Finals': 'Italy',
    'Doha Open': 'Qatar',
    'Estoril Open': 'Portugal',
    'Hungarian Open': 'Hungary',
    'Munich Open': 'Germany',
    'Umag Open': 'Croatia',
    'Gstaad Open': 'Switzerland',
    'Kitzbuhel Open': 'Austria',
    'Winston-Salem Open': 'United States of America',
    'Chengdu Open': 'China',
    'Zhuhai Championships': 'China',
    'China Open': 'China',
    'Shanghai Masters': 'China',
    'Stockholm Open': 'Sweden',
    'Shenzhen Open': 'China',
    'Casablanca Open': 'Morocco',
    'Brasil Open': 'Brazil',
    'Bucharest Open': 'Romania',
    'Newport Open': 'United States of America',
    'Bastad Open': 'Sweden',
    'Dubai Open': 'UAE',
    'Sybase Open': 'United States of America',
    'Kroger St. Jude': 'United States of America',
    'ABN AMRO World Tennis Tournament': 'Netherlands',
    'AXA Cup': 'United States of America',
    'Copenhagen Open': 'Denmark',
    'Citrix Tennis Championships': 'United States of America',
    'Chevrolet Cup': 'Chile',
    'Colombia Open': 'Colombia',
    'Franklin Templeton Tennis Classic': 'United States of America',
    'Indian Wells TMS': 'United States of America',
    'Ericsson Open': 'United States of America',
    'Galleryfurniture.com Tennis Challenge': 'United States of America',
    'Grand Prix Hassan II': 'Morocco',
    'Open Seat Godo': 'Spain',
    'Mallorca Open': 'Spain',
    'BMW Open': 'Germany',
    'U.S. Clay Court Championships': 'United States of America',
    'Rome TMS': 'Italy',
    'Hamburg TMS': 'Germany',
    'Internationaler Raiffeisen Grand Prix': 'Austria',
    'Gerry Weber Open': 'Germany',
    'Stella Artois': 'UK',
    'Nottingham Open': 'UK',
    'Heineken Trophy': 'Netherlands',
    'Swedish Open': 'Sweden',
    'Hall of Fame Championships': 'United States of America',
    'Dutch Open': 'Netherlands',
    'Mercedes Cup': 'Germany',
    'Generali Open': 'Austria',
    'Mercedes-Benz Cup': 'United States of America',
    "Tennis Int'l of San Marino": 'San Marino',
    'Toronto TMS': 'Canada',
    'Cincinnati TMS': 'United States of America',
    'RCA Championships': 'United States of America',
    'Legg Mason Classic': 'United States of America',
    'The Hamlet Cup': 'United States of America',
    'Open Romania': 'Romania',
    "President's Cup": 'Kazakhstan',
    'Campionati Internazionali Di Sicilia': 'Italy',
    'Salem Open': 'China',
    'Japan Open': 'Japan',
    'CA Tennis Trophy': 'Austria',
    'Heineken Open Shanghai': 'China',
    'adidas Open': 'France',
    'Swiss Indoors': 'Switzerland',
    'Kremlin Cup': 'Russia',
    'Stuttgart TMS': 'Germany',
    'Grand Prix de Lyon': 'France',
    'BNP Paribas': 'France',
    'Samsung Open': 'South Korea',
    'Masters Cup': 'China',
    'AAPT Championships': 'Australia',
    'TATA Open': 'India',
    'adidas International': 'Australia',
    'Milan Indoors': 'Italy',
    'Bellsouth Open': 'United States of America',
    'Copa AT&T': 'Argentina',
    'Abierto Mexicano': 'Mexico',
    'Dubai Championships': 'UAE',
    'Verizon Tennis Challenge': 'United States of America',
    "U.S. Men's Clay Court Championships": 'United States of America',
    'Idea Prokom Open': 'Poland',
    'Montreal TMS': 'Canada',
    'Hamlet Cup': 'United States of America',
    'Gelsor Open': 'Thailand',
    'Pacific Life Open': 'United States of America',
    'NASDAQ-100 Open': 'United States of America',
    'Queens Club': 'UK',
    'Ordina Open': 'Netherlands',
    'Energis Open': 'UK',
    'TD Waterhouse Cup': 'United States of America',
    'Madrid Masters': 'Spain',
    'Qatar Exxon Mobil Open': 'Qatar',
    'Breil ATP': 'Italy',
    'Open 13': 'France',
    'Siebel Open': 'United States of America',
    'International Championships': 'UK',
    'CAM Open Comunidad Valenciana': 'Spain',
    'Telecom Italia Masters Roma': 'Italy',
    'Allianz Suisse Open': 'Switzerland',
    'Priority Telecom Dutch Open': 'Netherlands',
    'Western & Southern Financial Group Masters': 'United States of America',
    'Thailand Open': 'Thailand',
    'Open de Moselle': 'France',
    'Indesit ATP Milano Indoor ': 'Italy',
    'ATP Buenos Aires 2004': 'Argentina',
    'Next Generation Hardcourts': 'Australia',
    'Medibank International': 'Australia',
    'Internazionali di Lombardia': 'Italy',
    'ATP Buenos Aires 2005': 'Argentina',
    'SAP Open': 'United States of America',
    'Regions Morgan Keegan Championships': 'United States of America',
    "Dubai Duty Free Men's Open": 'UAE',
    'Channel Open': 'United States of America',
    'Open de Tenis Comunidad Valenciana': 'Spain',
    'Rogers Cup': 'Canada',
    'Pilot Pen Tennis': 'United States of America',
    'Vietnam Open': 'Vietnam',
    'BA-CA Tennis Trophy': 'Austria',
    'Davidoff Swiss Indoors': 'Switzerland',
    'Next Generation Adelaide International': 'Australia',
    'Chennai Open': 'India',
    'Movistar Open': 'Chile',
    'PBZ Zagreb Indoors': 'Croatia',
    'Copa Telmex': 'Argentina',
    "Campionati Internazional d'Italia": 'Italy',
    'Hypo Group Tennis International': 'Austria',
    'Red Letter Days Open': 'UK',
    'Synsam Swedish Open': 'Sweden',
    'Countrywide Classic': 'United States of America',
    'Rogers Masters': 'Canada',
    'Kingfisher Airlines Tennis Open': 'India',
    'Sony Ericsson Open': 'United States of America',
    "Internazionali BNL d'Italia": 'Italy',
    'The Nottingham Open': 'UK',
    'Catella Swedish Open': 'Sweden',
    'Indianapolis Tennis Championships': 'United States of America',
    'Austrian Open': 'Austria',
    'AIG Japan Open Tennis Championships': 'Japan',
    'Open Sabadell Atlántico 2008': 'Spain',
    'Orange Prokom Open': 'Poland',
    'Slazenger Open': 'UK',
    'Studena Croatia Open': 'Croatia',
    'SA Tennis Open': 'South Africa',
    'BNP Paribas Open': 'United States of America',
    'Open Banco Sabadell': 'Spain',
    'Serbia Open': 'Serbia',
    'Mutua Madrileña Madrid Open': 'Spain',
    'AEGON Championships': 'UK',
    'AEGON International': 'UK',
    'International German Open': 'Germany',
    'LA Tennis Open': 'United States of America',
    'Proton Malaysian Open': 'Malaysia',
    'Rakuten Japan Open Tennis Championships': 'Japan',
    'Valencia Open 500': 'Spain',
    'BNP Paribas Masters': 'France',
    'Unicef Open': 'Netherlands',
    'SkiStar Swedish Open': 'Sweden',
    'Atlanta Tennis Championships': 'United States of America',
    'German Open Tennis Championships': 'Germany',
    'Farmers Classic': 'United States of America',
    'Open Sud de France': 'France',
    'Copa Claro': 'Argentina',
    'Bet-At-Home Cup': 'Austria',
    'Winston-Salem Open at Wake Forest University': 'United States of America',
    'Malaysian Open': 'Malaysia',
    'Apia International': 'Australia',
    'VTR Open': 'Chile',
    'BRD Nastase Tiriac Trophy': 'Romania',
    'Mutua Madrid Open': 'Spain',
    'ATP Vegeta Croatia Open': 'Croatia',
    'BB&T Atlanta Open': 'United States of America',
    'Crédit Agricole Suisse Open Gstaad': 'Switzerland',
    'Citi Open': 'United States of America',
    'U.S. National Indoor Tennis Championships': 'United States of America',
    'Portugal Open': 'Portugal',
    'Power Horse Cup': 'Germany',
    'Topshelf Open': 'Netherlands',
    'Claro Open Colombia': 'Colombia',
    'Royal Guard Open Chile': 'Chile',
    'Dusseldorf Open': 'Germany',
    'bet-at-home Open': 'Germany',
    'Ecuador Open': 'Ecuador',
    'Memphis Open': 'United States of America',
    'Argentina Open': 'Argentina',
    'Millenium Estoril Open': 'Portugal',
    'Istanbul Open': 'Turkey',
    'AEGON Open': 'UK',
    'Konzum Croatia Open': 'Croatia',
    'Suisse Open Gstaad': 'Switzerland',
    'ASB Classic': 'New Zealand',
    'Garanti Koza Sofia Open': 'Bulgaria',
    'German Tennis Championships': 'Germany',
    'Abierto Mexicano Mifel': 'Mexico',
    'European Open': 'Belgium',
    'Open Banco Sabadell ': 'Spain',
    'Gazprom Hungarian Open': 'Hungary',
    'Ricoh Open': 'Netherlands',
    'Antalya Open': 'Turkey',
    'Tata Open': 'India',
    'New York Open': 'United States of America',
    'Millennium Estoril Open': 'Portugal',
    'Maharashtra Open': 'India',
    'Cordoba Open': 'Argentina',
    'Rosmalen Grass Court Championships': 'Netherlands',
    "Queen's Club Championships": 'UK',
    'Zhuhai Open': 'China',
    'bett1HULKS Indoors': 'Germany',
    'Forte Village Sardegna Open': 'Italy',
    'bett1HULKS Championship': 'Germany',
    'Astana Open': 'Kazakhstan',
    'Great Ocean Road Open': 'Australia',
    'Murray River Open': 'Australia',
    'Singapore Open': 'Singapore',
    'Sardegna Open': 'Italy',
    'AnyTech365 Andalucia Open': 'Spain',
    'Belgrade Open': 'Serbia',
    'Emilia-Romagna Open': 'Italy',
    'Viking International': 'UK',
    'Mallorca Championships': 'Spain',
    'Nordea Open': 'Sweden',
    'Mifel Open': 'Mexico',
    'Canadian Open': 'Canada',
    'San Diego Open': 'United States of America',
    'Adelaide International 1': 'Australia',
    'Melbourne Summer Set': 'Australia',
    'Adelaide International 2': 'Australia',
    'Sydney Tennis Classic': 'Australia',
    'Dallas Open': 'United States of America',
    'Korea Open': 'South Korea',
    'Tel Aviv Open': 'Israel',
    'Firenze Open': 'Italy',
    'Gijon Open': 'Spain',
    'Napoli Cup': 'Italy',
    'Srpska Open': 'Bosnia and Herzegovina',
    'Nordic Open': 'Denmark',
    'Japan Open Tennis Championships': 'Japan',
    'Hong Kong Tennis Open': 'Hong Kong',
    'Tiriac Open': 'Romania',
    'Hangzhou Open': 'China',
    'Almaty Open': 'Kazakhstan',
    "Open de Nice Côte d’Azur": 'France'
}

# Applica le corrispondenze al dataframe tramite map per parallelizzare
df['Country'] = df['Tournament'].map(tournament_country)

# Salva il dataframe aggiornato
df.to_csv('atp_tennis.csv', index=False)

# Verifica se ci sono tornei senza paese assegnato
tornei_senza_paese = df[df['Country'].isna()]['Tournament'].unique()
if len(tornei_senza_paese) > 0:
    print("Tornei senza paese assegnato:")
    print(tornei_senza_paese)
    print(len(tornei_senza_paese))
else:
    print("Tutti i tornei hanno un paese assegnato")
# Out:
# Tutti i tornei hanno un paese assegnato

# %%
# Fondere Carpet e Hard, sono la stessa superficie
# Sostituisci 'Carpet' con 'Hard' nella colonna 'Surface'
df.loc[df['Surface'] == 'Carpet', 'Surface'] = 'Hard'

# Salva il dataframe modificato
df.to_csv('atp_tennis.csv', index=False)

# %%
# Sostituisci 'China' con 'Italy' per le righe in cui il torneo è 'Masters Cup'
df.loc[df['Tournament'] == 'Masters Cup', 'Country'] = 'Italy'

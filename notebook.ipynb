# %%
# !pip3.13 install pandas matplotlib seaborn numpy scipy folium geopandas

# %%
# Importazione delle librerie necessarie
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Caricamento del dataset
# Sostituisci 'path_to_dataset.csv' con il percorso al tuo file CSV contenente i dati
try:
    df = pd.read_csv('Datasets/atp_tennis.csv')
except FileNotFoundError:
    print("Errore: Il file specificato non è stato trovato. Verifica il percorso.")

# %% [markdown]
# Analisi della Distribuzione dei Campi Odd_1 e Odd_2

# %%
# Configurazione estetica dei grafici
sns.set_theme(style="whitegrid", palette="pastel")

# Rimozione dei valori nulli o gestione
df = df.dropna(subset=['Odd_1', 'Odd_2'])  # Rimuove le righe con valori nulli in Odd_1 o Odd_2

# Creazione degli istogrammi
plt.figure(figsize=(14, 6))

# Istogramma per Odd_1
plt.subplot(1, 2, 1)
sns.histplot(df['Odd_1'], bins=20, kde=True, color="blue", stat="density", edgecolor="black")
plt.title('Distribuzione di Odd_1')
plt.xlabel('Odd_1')
plt.ylabel('Densità')
plt.xlim(0, 20)

# Istogramma per Odd_2
plt.subplot(1, 2, 2)
sns.histplot(df['Odd_2'], bins=20, kde=True, color="orange", stat="density", edgecolor="black")
plt.title('Distribuzione di Odd_2')
plt.xlabel('Odd_2')
plt.ylabel('Densità')
plt.xlim(0, 20)

# Mostra i grafici
plt.tight_layout()
plt.show()

# %% [markdown]
# Codice per la Distribuzione di Rank_1 e Rank_2

# %%
# Pulisci i dati rimuovendo eventuali valori nulli
df = df.dropna(subset=['Rank_1', 'Rank_2'])

# Esplora la distribuzione dei ranking
plt.figure(figsize=(14, 6))

# Istogramma per Rank_1 (Giocatore 1)
plt.subplot(1, 2, 1)
sns.histplot(df['Rank_1'], bins=20, kde=True, color="blue", edgecolor="black")
plt.title('Distribuzione di Rank_1 (Giocatore 1)')
plt.xlabel('Rank_1')
plt.ylabel('Frequenza')
plt.xlim(0, 1000)

# Istogramma per Rank_2 (Giocatore 2)
plt.subplot(1, 2, 2)
sns.histplot(df['Rank_2'], bins=20, kde=True, color="orange", edgecolor="black")
plt.title('Distribuzione di Rank_2 (Giocatore 2)')
plt.xlabel('Rank_2')
plt.ylabel('Frequenza')
plt.xlim(0, 1000)

# Mostra i grafici
plt.tight_layout()
plt.show()

# %% [markdown]
# Distribuzione delle Vittorie per Giocatore

# %%
# Conta le vittorie per ciascun giocatore
winner_counts = df['Winner'].value_counts()

# Seleziona i primi 30 giocatori più vincenti
top_20_winners = winner_counts.head(30)

# Esplora la distribuzione delle vittorie
plt.figure(figsize=(10, 8))

# Istogramma con i giocatori sull'asse Y e il numero di vittorie sull'asse X
sns.barplot(x=top_20_winners.values, y=top_20_winners.index, palette='viridis', edgecolor='black')

# Titolo e etichette
plt.title('Top 20 Giocatori Più Vincenti')
plt.xlabel('Numero di Vittorie')
plt.ylabel('Giocatori')
plt.xticks(ticks=range(0, int(top_20_winners.values.max()) + 100, 100))

# Mostra il grafico
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/2291981916.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_20_winners.values, y=top_20_winners.index, palette='viridis', edgecolor='black')

# %% [markdown]
#  Istogrammi di Rank_1, Rank_2, Pts_1 e Pts_2

# %%
# Esplora la distribuzione di Rank_1, Rank_2, Pts_1, Pts_2
plt.figure(figsize=(14, 10))

# Istogramma per Rank_1 (Rank del Giocatore 1)
plt.subplot(2, 2, 1)
sns.histplot(df['Rank_1'], bins=20, kde=True, color="blue", edgecolor="black")
plt.title('Distribuzione di Rank_1 (Giocatore 1)')
plt.xlabel('Rank_1')
plt.ylabel('Frequenza')

# Istogramma per Rank_2 (Rank del Giocatore 2)
plt.subplot(2, 2, 2)
sns.histplot(df['Rank_2'], bins=20, kde=True, color="orange", edgecolor="black")
plt.title('Distribuzione di Rank_2 (Giocatore 2)')
plt.xlabel('Rank_2')
plt.ylabel('Frequenza')

# Istogramma per Pts_1 (Punteggio del Giocatore 1)
plt.subplot(2, 2, 3)
sns.histplot(df['Pts_1'], bins=20, kde=True, color="green", edgecolor="black")
plt.title('Distribuzione di Pts_1 (Giocatore 1)')
plt.xlabel('Pts_1')
plt.ylabel('Frequenza')

# Istogramma per Pts_2 (Punteggio del Giocatore 2)
plt.subplot(2, 2, 4)
sns.histplot(df['Pts_2'], bins=20, kde=True, color="red", edgecolor="black")
plt.title('Distribuzione di Pts_2 (Giocatore 2)')
plt.xlabel('Pts_2')
plt.ylabel('Frequenza')

# Mostra i grafici
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafico a barre per il numero di partite giocate su ciascuna superficie o in ciascun round.

# %%
# Grafico a barre per il numero di partite giocate su ciascuna superficie
plt.figure(figsize=(14, 6))

# Grafico a barre per la superficie
plt.subplot(1, 2, 1)
sns.countplot(data=df, x='Surface', palette='viridis', edgecolor='black')
plt.title('Numero di Partite per Superficie')
plt.xlabel('Superficie')
plt.ylabel('Numero di Partite')
plt.xticks(rotation=45)  # Ruota le etichette delle superfici per una lettura migliore

# Grafico a barre per il numero di partite giocate in ciascun round
plt.subplot(1, 2, 2)
sns.countplot(data=df, x='Round', palette='viridis', edgecolor='black')
plt.title('Numero di Partite per Round')
plt.xlabel('Round')
plt.ylabel('Numero di Partite')
plt.xticks(rotation=45)  # Ruota le etichette dei round per una lettura migliore

# Mostra i grafici
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/4120286739.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Surface', palette='viridis', edgecolor='black')
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/4120286739.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Round', palette='viridis', edgecolor='black')

# %% [markdown]
# matrice di correlazione tra le variabili Rank_1, Rank_2, Pts_1, e Pts_2

# %%
#Ha più senso Pts e Partite Vinte (da calcolare) per anno




# Seleziona solo le colonne di interesse per la correlazione
columns_of_interest = ['Rank_1', 'Rank_2', 'Pts_1', 'Pts_2']

# Calcola la matrice di correlazione
correlation_matrix = df[columns_of_interest].corr()

# Visualizza la matrice di correlazione come una heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Titolo e visualizzazione
plt.title('Matrice di Correlazione tra Rank_1, Rank_2, Pts_1 e Pts_2')
plt.tight_layout()
plt.show()

# %% [markdown]
# Vincitori a seconda del tipo di suolo

# %%
from scipy import stats

# %%
# Conta le vittorie per ciascun tennista e seleziona i 30 più vincenti
top_30_winners = df['Winner'].value_counts().head(30).index

# Filtra il dataset per includere solo i 30 tennisti più vincenti
df_top_30 = df[df['Winner'].isin(top_30_winners)]

# Creazione dei grafici
plt.figure(figsize=(16, 12))

# Grafico per i tennisti più vincenti su "Clay"
plt.subplot(2, 2, 1)
clay_winners = df_top_30[df_top_30['Surface'] == 'Clay']['Winner'].value_counts()
sns.barplot(x=clay_winners.values, y=clay_winners.index, palette='viridis', edgecolor='black')
plt.title('Vincitori su Clay')
plt.xlabel('Numero di Vittorie')
plt.ylabel('Tennisti')
plt.xticks(rotation=45)

# Grafico per i tennisti più vincenti su "Hard"
plt.subplot(2, 2, 2)
hard_winners = df_top_30[df_top_30['Surface'] == 'Hard']['Winner'].value_counts()
sns.barplot(x=hard_winners.values, y=hard_winners.index, palette='viridis', edgecolor='black')
plt.title('Vincitori su Hard')
plt.xlabel('Numero di Vittorie')
plt.ylabel('Tennisti')
plt.xticks(rotation=45)

# Grafico per i tennisti più vincenti su "Grass"
plt.subplot(2, 2, 3)
grass_winners = df_top_30[df_top_30['Surface'] == 'Grass']['Winner'].value_counts()
sns.barplot(x=grass_winners.values, y=grass_winners.index, palette='viridis', edgecolor='black')
plt.title('Vincitori su Grass')
plt.xlabel('Numero di Vittorie')
plt.ylabel('Tennisti')
plt.xticks(rotation=45)

# Grafico per i tennisti più vincenti su "Carpet" (se presente)
plt.subplot(2, 2, 4)
carpet_winners = df_top_30[df_top_30['Surface'] == 'Carpet']['Winner'].value_counts()
sns.barplot(x=carpet_winners.values, y=carpet_winners.index, palette='viridis', edgecolor='black')
plt.title('Vincitori su Carpet')
plt.xlabel('Numero di Vittorie')
plt.ylabel('Tennisti')
plt.xticks(rotation=45)

# Layout e visualizzazione
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/3546990453.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=clay_winners.values, y=clay_winners.index, palette='viridis', edgecolor='black')
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/3546990453.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hard_winners.values, y=hard_winners.index, palette='viridis', edgecolor='black')
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/3546990453.py:31: FutureWarning:
#
# ...

# %%
# Estrai l'anno dalla colonna 'Date'
df['Anno'] = pd.to_datetime(df['Date']).dt.year

# Conta il numero di tornei per anno
tornei_per_anno = df.groupby('Anno').size()

# Crea il grafico con uno stile più accattivante
plt.style.use('seaborn')
plt.figure(figsize=(14, 6))

# Plot principale con area ombreggiata
plt.fill_between(tornei_per_anno.index, tornei_per_anno.values, alpha=0.3, color='#2ecc71')
sns.lineplot(x=tornei_per_anno.index, y=tornei_per_anno.values, 
            marker='o', color='#27ae60', linewidth=5.5,
            markersize=8)

# Personalizzazione del grafico
plt.title('Evoluzione del Numero di Tornei nel Tempo', pad=20, fontsize=16, fontweight='bold')
plt.xlabel('Anno', fontsize=12, fontweight='bold')
plt.ylabel('Numero di Tornei', fontsize=12, fontweight='bold')

# Griglia e bordi
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45)

# Aggiunta di annotazioni per i valori massimi e minimi
max_year = tornei_per_anno.idxmax()
max_value = tornei_per_anno.max()
min_year = tornei_per_anno.idxmin()
min_value = tornei_per_anno.min()

plt.annotate(f'Massimo: {max_value}',
            xy=(max_year, max_value), xytext=(10, 10),
            textcoords='offset points', ha='left',
            bbox=dict(boxstyle='round,pad=0.5', fc='#2ecc71', alpha=0.3),
            fontsize=10)

plt.annotate(f'Minimo: {min_value}',
            xy=(min_year, min_value), xytext=(10, -15),
            textcoords='offset points', ha='left',
            bbox=dict(boxstyle='round,pad=0.5', fc='#2ecc71', alpha=0.3),
            fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/matplotlib/__init__.py:870, in _rc_params_in_file(fname, transform, fail_on_error)
#     869 rc_temp = {}
# --> 870 with _open_file_or_url(fname) as fd:
#     871     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# ...

# %%
# Filtra i match di Federer (sia come Player_1 che come Player_2)
federer_matches = df[(df['Player_1'] == 'Federer R.') | (df['Player_2'] == 'Federer R.')].copy()

# Estrai l'anno dalla colonna Date
federer_matches['Year'] = pd.to_datetime(federer_matches['Date']).dt.year

# Calcola vittorie, sconfitte e percentuale vittorie per anno
federer_stats = []
for year in federer_matches['Year'].unique():
    year_matches = federer_matches[federer_matches['Year'] == year]
    
    # Conta vittorie quando Federer è Player_1 o Player_2
    wins = len(year_matches[
        ((year_matches['Player_1'] == 'Federer R.') & (year_matches['Winner'] == 'Federer R.')) |
        ((year_matches['Player_2'] == 'Federer R.') & (year_matches['Winner'] == 'Federer R.'))
    ])
    
    # Il totale delle partite meno le vittorie sono le sconfitte
    total_matches = len(year_matches)
    losses = total_matches - wins
    
    # Calcola la percentuale di vittorie
    win_percentage = (wins / total_matches) * 100
    
    federer_stats.append({
        'Year': year, 
        'Vittorie': wins, 
        'Sconfitte': losses,
        'Percentuale_Vittorie': win_percentage
    })

# Converti in DataFrame
federer_stats_df = pd.DataFrame(federer_stats)

# Crea la figura
plt.figure(figsize=(18, 12))
plt.style.use('seaborn')

# Plot delle vittorie e sconfitte (barre)
plt.bar(federer_stats_df['Year'], federer_stats_df['Vittorie'], 
        color='#27ae60', label='Vittorie', alpha=0.7, width=0.8)
plt.bar(federer_stats_df['Year'], federer_stats_df['Sconfitte'], 
        bottom=federer_stats_df['Vittorie'], color='#e74c3c', 
        label='Sconfitte')

# Personalizzazione del grafico
plt.title('Statistiche di Roger Federer per Anno', pad=20, fontsize=24, fontweight='bold')
plt.xlabel('Anno', fontsize=18, fontweight='bold')
plt.ylabel('Numero di Partite', fontsize=18, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.3)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)

# Aggiungi la legenda con font più grande
plt.legend(loc='upper left', fontsize=16)

# Aggiungi le etichette delle percentuali sopra ogni barra
for i, row in federer_stats_df.iterrows():
    total_height = row['Vittorie'] + row['Sconfitte']
    plt.annotate(f'%W: {row["Percentuale_Vittorie"]:.1f}%',
                xy=(row['Year'], total_height),
                xytext=(0, 5), textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9,
                bbox=dict(boxstyle='round,pad=0.5', fc='white', ec='gray', alpha=0.7))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/3597859059.py:37: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Filtra i match di Nadal (sia come Player_1 che come Player_2)
nadal_matches = df[(df['Player_1'] == 'Nadal R.') | (df['Player_2'] == 'Nadal R.')].copy()

# Estrai l'anno dalla colonna Date
nadal_matches['Year'] = pd.to_datetime(nadal_matches['Date']).dt.year

# Calcola vittorie, sconfitte e percentuale vittorie per anno
nadal_stats = []
for year in nadal_matches['Year'].unique():
    year_matches = nadal_matches[nadal_matches['Year'] == year]
    
    # Conta vittorie quando Nadal è Player_1 o Player_2
    wins = len(year_matches[
        ((year_matches['Player_1'] == 'Nadal R.') & (year_matches['Winner'] == 'Nadal R.')) |
        ((year_matches['Player_2'] == 'Nadal R.') & (year_matches['Winner'] == 'Nadal R.'))
    ])
    
    # Il totale delle partite meno le vittorie sono le sconfitte
    total_matches = len(year_matches)
    losses = total_matches - wins
    
    # Calcola la percentuale di vittorie
    win_percentage = (wins / total_matches) * 100
    
    nadal_stats.append({
        'Year': year, 
        'Vittorie': wins, 
        'Sconfitte': losses,
        'Percentuale_Vittorie': win_percentage
    })

# Converti in DataFrame
nadal_stats_df = pd.DataFrame(nadal_stats)

# Crea la figura
plt.figure(figsize=(18, 12))
plt.style.use('seaborn')

# Plot delle vittorie e sconfitte (barre)
plt.bar(nadal_stats_df['Year'], nadal_stats_df['Vittorie'], 
        color='#27ae60', label='Vittorie', alpha=0.7, width=0.8)
plt.bar(nadal_stats_df['Year'], nadal_stats_df['Sconfitte'], 
        bottom=nadal_stats_df['Vittorie'], color='#e74c3c', 
        label='Sconfitte')

# Personalizzazione del grafico
plt.title('Statistiche di Rafael Nadal per Anno', pad=20, fontsize=24, fontweight='bold')
plt.xlabel('Anno', fontsize=18, fontweight='bold')
plt.ylabel('Numero di Partite', fontsize=18, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.3)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)

# Aggiungi la legenda con font più grande
plt.legend(loc='upper left', fontsize=16)

# Aggiungi le etichette delle percentuali sopra ogni barra
for i, row in nadal_stats_df.iterrows():
    total_height = row['Vittorie'] + row['Sconfitte']
    plt.annotate(f'%W: {row["Percentuale_Vittorie"]:.1f}%',
                xy=(row['Year'], total_height),
                xytext=(0, 5), textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9,
                bbox=dict(boxstyle='round,pad=0.5', fc='white', ec='gray', alpha=0.7))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/1848995794.py:37: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Filtra i match di Djokovic (sia come Player_1 che come Player_2)
djokovic_matches = df[(df['Player_1'] == 'Djokovic N.') | (df['Player_2'] == 'Djokovic N.')].copy()

# Estrai l'anno dalla colonna Date
djokovic_matches['Year'] = pd.to_datetime(djokovic_matches['Date']).dt.year

# Calcola vittorie, sconfitte e percentuale vittorie per anno
djokovic_stats = []
for year in djokovic_matches['Year'].unique():
    year_matches = djokovic_matches[djokovic_matches['Year'] == year]
    
    # Conta vittorie quando Djokovic è Player_1 o Player_2
    wins = len(year_matches[
        ((year_matches['Player_1'] == 'Djokovic N.') & (year_matches['Winner'] == 'Djokovic N.')) |
        ((year_matches['Player_2'] == 'Djokovic N.') & (year_matches['Winner'] == 'Djokovic N.'))
    ])
    
    # Il totale delle partite meno le vittorie sono le sconfitte
    total_matches = len(year_matches)
    losses = total_matches - wins
    
    # Calcola la percentuale di vittorie
    win_percentage = (wins / total_matches) * 100
    
    djokovic_stats.append({
        'Year': year, 
        'Vittorie': wins, 
        'Sconfitte': losses,
        'Percentuale_Vittorie': win_percentage
    })

# Converti in DataFrame
djokovic_stats_df = pd.DataFrame(djokovic_stats)

# Crea la figura
plt.figure(figsize=(18, 12))
plt.style.use('seaborn')

# Plot delle vittorie e sconfitte (barre)
plt.bar(djokovic_stats_df['Year'], djokovic_stats_df['Vittorie'], 
        color='#27ae60', label='Vittorie', alpha=0.7, width=0.8)
plt.bar(djokovic_stats_df['Year'], djokovic_stats_df['Sconfitte'], 
        bottom=djokovic_stats_df['Vittorie'], color='#e74c3c', 
        label='Sconfitte')

# Personalizzazione del grafico
plt.title('Statistiche di Novak Djokovic per Anno', pad=20, fontsize=24, fontweight='bold')
plt.xlabel('Anno', fontsize=18, fontweight='bold')
plt.ylabel('Numero di Partite', fontsize=18, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.3)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)

# Aggiungi la legenda con font più grande
plt.legend(loc='upper left', fontsize=16)

# Aggiungi le etichette delle percentuali sopra ogni barra
for i, row in djokovic_stats_df.iterrows():
    total_height = row['Vittorie'] + row['Sconfitte']
    plt.annotate(f'%W: {row["Percentuale_Vittorie"]:.1f}%',
                xy=(row['Year'], total_height),
                xytext=(0, 5), textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9,
                bbox=dict(boxstyle='round,pad=0.5', fc='white', ec='gray', alpha=0.7))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/3497729605.py:37: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Funzione per calcolare le statistiche di vittorie per un giocatore
def calcola_statistiche_vittorie(df, player_name):
    player_matches = df[(df['Player_1'] == player_name) | (df['Player_2'] == player_name)].copy()
    player_matches['Year'] = pd.to_datetime(player_matches['Date']).dt.year
    
    player_stats = []
    for year in player_matches['Year'].unique():
        year_matches = player_matches[player_matches['Year'] == year]
        wins = len(year_matches[year_matches['Winner'] == player_name])
        total_matches = len(year_matches)
        win_percentage = (wins / total_matches) * 100 if total_matches > 0 else 0
        
        player_stats.append({
            'Year': year, 
            'Percentuale_Vittorie': win_percentage
        })
    
    return pd.DataFrame(player_stats)

# Calcola le statistiche per ciascun giocatore
federer_stats_df = calcola_statistiche_vittorie(df, 'Federer R.')
nadal_stats_df = calcola_statistiche_vittorie(df, 'Nadal R.')
djokovic_stats_df = calcola_statistiche_vittorie(df, 'Djokovic N.')

# Crea il grafico
plt.figure(figsize=(16, 9))
plt.style.use('seaborn-darkgrid')

# Plot delle percentuali di vittorie
sns.lineplot(data=federer_stats_df, x='Year', y='Percentuale_Vittorie', marker='o', label='Federer', color='#1f77b4', linewidth=2.5)
sns.lineplot(data=nadal_stats_df, x='Year', y='Percentuale_Vittorie', marker='o', label='Nadal', color='#ff7f0e', linewidth=2.5)
sns.lineplot(data=djokovic_stats_df, x='Year', y='Percentuale_Vittorie', marker='o', label='Djokovic', color='#2ca02c', linewidth=2.5)

# Personalizzazione del grafico
plt.title('Andamento Percentuale di Vittorie per Anno', pad=20, fontsize=22, fontweight='bold')
plt.xlabel('Anno', fontsize=16, fontweight='bold')
plt.ylabel('Percentuale di Vittorie (%)', fontsize=16, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Aggiungi la legenda
plt.legend(loc='upper left', fontsize=14)

# Annotazioni per i punti di massimo e minimo
for stats_df, color in zip([federer_stats_df, nadal_stats_df, djokovic_stats_df], ['#1f77b4', '#ff7f0e', '#2ca02c']):
    max_year = stats_df.loc[stats_df['Percentuale_Vittorie'].idxmax()]['Year']
    max_value = stats_df['Percentuale_Vittorie'].max()
    plt.annotate(f'Max: {max_value:.1f}%', xy=(max_year, max_value), xytext=(5, 5), textcoords='offset points', ha='center', color=color, fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/4213827227.py:27: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
# Filtra i match di Sinner (sia come Player_1 che come Player_2)
sinner_matches = df[(df['Player_1'] == 'Sinner J.') | (df['Player_2'] == 'Sinner J.')].copy()

# Estrai l'anno dalla colonna Date
sinner_matches['Year'] = pd.to_datetime(sinner_matches['Date']).dt.year

# Calcola vittorie, sconfitte e percentuale vittorie per anno
sinner_stats = []
for year in sinner_matches['Year'].unique():
    year_matches = sinner_matches[sinner_matches['Year'] == year]
    
    # Conta vittorie quando Sinner è Player_1 o Player_2
    wins = len(year_matches[
        ((year_matches['Player_1'] == 'Sinner J.') & (year_matches['Winner'] == 'Sinner J.')) |
        ((year_matches['Player_2'] == 'Sinner J.') & (year_matches['Winner'] == 'Sinner J.'))
    ])
    
    # Il totale delle partite meno le vittorie sono le sconfitte
    total_matches = len(year_matches)
    losses = total_matches - wins
    
    # Calcola la percentuale di vittorie
    win_percentage = (wins / total_matches) * 100 if total_matches > 0 else 0
    
    sinner_stats.append({
        'Year': year, 
        'Vittorie': wins, 
        'Sconfitte': losses,
        'Percentuale_Vittorie': win_percentage
    })

# Converti in DataFrame
sinner_stats_df = pd.DataFrame(sinner_stats)

# Crea la figura
plt.figure(figsize=(18, 12))
plt.style.use('seaborn')

# Plot delle vittorie e sconfitte (barre)
plt.bar(sinner_stats_df['Year'], sinner_stats_df['Vittorie'], 
        color='#27ae60', label='Vittorie', alpha=0.7, width=0.8)
plt.bar(sinner_stats_df['Year'], sinner_stats_df['Sconfitte'], 
        bottom=sinner_stats_df['Vittorie'], color='#e74c3c', 
        label='Sconfitte')

# Personalizzazione del grafico
plt.title('Statistiche di Jannik Sinner per Anno', pad=20, fontsize=24, fontweight='bold')
plt.xlabel('Anno', fontsize=18, fontweight='bold')
plt.ylabel('Numero di Partite', fontsize=18, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.3)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)

# Aggiungi la legenda con font più grande
plt.legend(loc='upper left', fontsize=16)

# Aggiungi le etichette delle percentuali sopra ogni barra
for i, row in sinner_stats_df.iterrows():
    total_height = row['Vittorie'] + row['Sconfitte']
    plt.annotate(f'%W: {row["Percentuale_Vittorie"]:.1f}%',
                xy=(row['Year'], total_height),
                xytext=(0, 5), textcoords='offset points',
                ha='center', va='bottom',
                fontsize=9,
                bbox=dict(boxstyle='round,pad=0.5', fc='white', ec='gray', alpha=0.7))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/2091751341.py:37: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Funzione per calcolare le statistiche di vittorie per un giocatore
def calcola_statistiche_vittorie(df, player_name):
    player_matches = df[(df['Player_1'] == player_name) | (df['Player_2'] == player_name)].copy()
    player_matches['Year'] = pd.to_datetime(player_matches['Date']).dt.year
    
    player_stats = []
    for year in player_matches['Year'].unique():
        year_matches = player_matches[player_matches['Year'] == year]
        wins = len(year_matches[year_matches['Winner'] == player_name])
        total_matches = len(year_matches)
        win_percentage = (wins / total_matches) * 100 if total_matches > 0 else 0
        
        player_stats.append({
            'Year': year, 
            'Percentuale_Vittorie': win_percentage
        })
    
    return pd.DataFrame(player_stats)

# Calcola le statistiche per Sinner e Alcaraz
sinner_stats_df = calcola_statistiche_vittorie(df, 'Sinner J.')
alcaraz_stats_df = calcola_statistiche_vittorie(df, 'Alcaraz C.')

# Crea il grafico
plt.figure(figsize=(14, 8))
plt.style.use('seaborn-darkgrid')

# Plot delle percentuali di vittorie
sns.lineplot(data=sinner_stats_df, x='Year', y='Percentuale_Vittorie', marker='o', label='Sinner', color='blue', linewidth=2.5)
sns.lineplot(data=alcaraz_stats_df, x='Year', y='Percentuale_Vittorie', marker='o', label='Alcaraz', color='orange', linewidth=2.5)

# Personalizzazione del grafico
plt.title('Confronto Percentuale di Vittorie tra Sinner e Alcaraz per Anno', pad=20, fontsize=20, fontweight='bold')
plt.xlabel('Anno', fontsize=14, fontweight='bold')
plt.ylabel('Percentuale di Vittorie (%)', fontsize=14, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Aggiungi la legenda
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/2478210316.py:26: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
# Funzione per calcolare le vittorie per un giocatore
def calcola_vittorie(df, player_name):
    # Filtra le partite in cui il giocatore è coinvolto
    player_matches = df[(df['Player_1'] == player_name) | (df['Player_2'] == player_name)].copy()
    # Estrai l'anno dalla colonna Date
    player_matches['Year'] = pd.to_datetime(player_matches['Date']).dt.year
    
    player_stats = []
    # Calcola le vittorie per ogni anno
    for year in player_matches['Year'].unique():
        year_matches = player_matches[player_matches['Year'] == year]
        wins = len(year_matches[year_matches['Winner'] == player_name])
        
        player_stats.append({
            'Year': year, 
            'Vittorie': wins
        })
    
    return pd.DataFrame(player_stats)

# Calcola le vittorie per Sinner e Alcaraz
sinner_vittorie_df = calcola_vittorie(df, 'Sinner J.')
alcaraz_vittorie_df = calcola_vittorie(df, 'Alcaraz C.')

# Unisci i dati per avere gli stessi anni
merged_df = pd.merge(sinner_vittorie_df, alcaraz_vittorie_df, on='Year', how='outer', suffixes=('_Sinner', '_Alcaraz')).fillna(0)

# Crea il grafico
plt.figure(figsize=(14, 8))
plt.style.use('seaborn-darkgrid')

# Larghezza delle barre
bar_width = 0.35

# Posizioni delle barre
r1 = np.arange(len(merged_df['Year']))
r2 = [x + bar_width for x in r1]

# Plot delle vittorie in numeri assoluti
plt.bar(r1, merged_df['Vittorie_Sinner'], color='blue', width=bar_width, label='Sinner', alpha=0.6)
plt.bar(r2, merged_df['Vittorie_Alcaraz'], color='orange', width=bar_width, label='Alcaraz', alpha=0.6)

# Personalizzazione del grafico
plt.title('Confronto Vittorie Assolute tra Sinner e Alcaraz per Anno', pad=20, fontsize=20, fontweight='bold')
plt.xlabel('Anno', fontsize=14, fontweight='bold')
plt.ylabel('Numero di Vittorie', fontsize=14, fontweight='bold')

# Aggiungi le etichette degli anni
plt.xticks([r + bar_width / 2 for r in range(len(merged_df['Year']))], merged_df['Year'], rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Aggiungi la legenda
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/2012602057.py:30: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
# Funzione per calcolare le vittorie per un giocatore
def calcola_vittorie(df, player_name):
    # Filtra le partite in cui il giocatore è coinvolto
    player_matches = df[(df['Player_1'] == player_name) | (df['Player_2'] == player_name)].copy()
    # Estrai l'anno dalla colonna Date
    player_matches['Year'] = pd.to_datetime(player_matches['Date']).dt.year
    
    player_stats = []
    # Calcola le vittorie per ogni anno
    for year in player_matches['Year'].unique():
        year_matches = player_matches[player_matches['Year'] == year]
        wins = len(year_matches[year_matches['Winner'] == player_name])
        
        player_stats.append({
            'Year': year, 
            'Vittorie': wins
        })
    
    return pd.DataFrame(player_stats)

# Calcola le vittorie per Sinner e Alcaraz
sinner_vittorie_df = calcola_vittorie(df, 'Sinner J.')
alcaraz_vittorie_df = calcola_vittorie(df, 'Alcaraz C.')

# Crea il grafico
plt.figure(figsize=(14, 8))
plt.style.use('seaborn-darkgrid')

# Plot delle vittorie in numeri assoluti
sns.lineplot(data=sinner_vittorie_df, x='Year', y='Vittorie', marker='o', label='Sinner', color='blue', linewidth=2.5)
sns.lineplot(data=alcaraz_vittorie_df, x='Year', y='Vittorie', marker='o', label='Alcaraz', color='orange', linewidth=2.5)

# Personalizzazione del grafico
plt.title('Andamento Vittorie Assolute tra Sinner e Alcaraz per Anno', pad=20, fontsize=20, fontweight='bold')
plt.xlabel('Anno', fontsize=14, fontweight='bold')
plt.ylabel('Numero di Vittorie', fontsize=14, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Aggiungi la legenda
plt.legend(loc='upper left', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/3301714940.py:27: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Filtra i dati per gli ultimi 5 anni
current_year = pd.to_datetime('today').year
recent_matches = df[pd.to_datetime(df['Date']).dt.year >= current_year - 5]

# Calcola le vittorie per ciascun tennista
def calcola_vittorie_annuali(df):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    vittorie = df.groupby(['Winner', 'Year']).size().reset_index(name='Vittorie')
    return vittorie

# Ottieni le vittorie annuali
vittorie_annuali = calcola_vittorie_annuali(recent_matches)

# Calcola il totale delle vittorie per ciascun tennista
totale_vittorie = vittorie_annuali.groupby('Winner')['Vittorie'].sum().reset_index()

# Seleziona i primi 10 tennisti
top_10_players = totale_vittorie.nlargest(10, 'Vittorie')['Winner']

# Filtra le vittorie annuali per i primi 10 tennisti
vittorie_top_10 = vittorie_annuali[vittorie_annuali['Winner'].isin(top_10_players)]

# Crea il grafico
plt.figure(figsize=(16, 10))
plt.style.use('seaborn-darkgrid')

# Colori personalizzati
colors = sns.color_palette('husl', len(top_10_players))
sinner_color = 'orange'

# Plot delle vittorie per ciascun tennista
for i, player in enumerate(top_10_players):
    player_data = vittorie_top_10[vittorie_top_10['Winner'] == player]
    color = sinner_color if player == 'Sinner J.' else colors[i]
    sns.lineplot(data=player_data, x='Year', y='Vittorie', label=player, color=color, linewidth=2.5)

# Personalizzazione del grafico
plt.title('Andamento Vittorie dei Primi 10 Tennisti negli Ultimi 5 Anni', pad=20, fontsize=20, fontweight='bold')
plt.xlabel('Anno', fontsize=14, fontweight='bold')
plt.ylabel('Numero di Vittorie', fontsize=14, fontweight='bold')

# Griglia e stile
plt.grid(True, linestyle='--', alpha=0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Rotazione delle etichette sull'asse x
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Aggiungi la legenda
plt.legend(loc='upper left', fontsize=10, ncol=2, bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/2311919964.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = pd.to_datetime(df['Date']).dt.year
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61032/2311919964.py:30: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcola il numero di tornei per ciascun paese
tornei_per_paese = df['Country'].value_counts()

# Crea il grafico a barre
plt.figure(figsize=(15, 8))
sns.barplot(x=tornei_per_paese.values, y=tornei_per_paese.index)

# Personalizzazione del grafico
plt.title('Distribuzione dei Tornei ATP per Paese', fontsize=14)
plt.xlabel('Numero di Tornei', fontsize=12)
plt.ylabel('Paese', fontsize=12)

# Mostra il grafico
plt.tight_layout()
plt.show()

# %%
# Calcola il numero di tornei unici per paese
tornei_unici_per_paese = df.groupby('Country')['Tournament'].nunique().reset_index()
tornei_unici_per_paese.columns = ['Country', 'Numero_Tornei']

# Visualizza i primi risultati per verifica
print("Distribuzione dei tornei unici per paese:")
print(tornei_unici_per_paese.sort_values('Numero_Tornei', ascending=False).head(10))
# Out:
# Distribuzione dei tornei unici per paese:
#                      Country  Numero_Tornei
# 46  United States of America             47
# 1                  Australia             17
# 45                        UK             15
# 39                     Spain             15
# 15                   Germany             15
# 20                     Italy             14
# 14                    France             11
# 9                      China             10
# 2                    Austria              9
# 27               Netherlands              9

# %%
# Crea la mappa
import geopandas as gpd
import matplotlib.pyplot as plt

# Carica il dataset mondiale dei confini dal file scaricato
world = gpd.read_file('110m_cultural/ne_110m_admin_0_countries.shp')

# Unisci i dati dei tornei con il dataset mondiale
world = world.merge(tornei_unici_per_paese, how='left', left_on=['NAME'], right_on=['Country'])

# Imposta il valore 0 per i paesi senza tornei
world['Numero_Tornei'] = world['Numero_Tornei'].fillna(0)

# Crea la figura con dimensioni personalizzate
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Crea la mappa
world.plot(column='Numero_Tornei', 
          ax=ax,
          legend=True,
          legend_kwds={'label': 'Numero di Tornei ATP Unici per Paese'},
          missing_kwds={'color': 'lightgrey'},
          cmap='YlOrRd')

# Personalizza il layout
plt.title('Distribuzione Mondiale dei Tornei ATP\n(Conteggio Tornei Unici)', fontsize=16, pad=20)
plt.axis('off')

# Mostra la mappa
plt.show()

# %%
# USA non viene preso nella mappa!!!

import pandas as pd

# Leggi il file CSV
df = pd.read_csv('Datasets/atp_tennis.csv')

# Sostituisci "USA" con "United States of America" nella colonna "Country"
df['Country'] = df['Country'].replace('USA', 'United States of America')

# Salva il dataframe modificato nel file CSV
df.to_csv('Datasets/atp_tennis.csv', index=False)

# %%
# Verifica le modifiche
# Calcola il numero di tornei unici per paese
tornei_unici_per_paese = df.groupby('Country')['Tournament'].nunique().reset_index()
tornei_unici_per_paese.columns = ['Country', 'Numero_Tornei']

# Visualizza i primi risultati per verifica
print("Distribuzione dei tornei unici per paese:")
print(tornei_unici_per_paese.sort_values('Numero_Tornei', ascending=False).head(10))
# Out:
# Distribuzione dei tornei unici per paese:
#                      Country  Numero_Tornei
# 46  United States of America             47
# 1                  Australia             17
# 45                        UK             15
# 39                     Spain             15
# 15                   Germany             15
# 20                     Italy             14
# 14                    France             11
# 9                      China             10
# 2                    Austria              9
# 27               Netherlands              9

# %%
# Crea la mappa
import geopandas as gpd
import matplotlib.pyplot as plt

# Carica il dataset mondiale dei confini dal file scaricato
world = gpd.read_file('110m_cultural/ne_110m_admin_0_countries.shp')

# Unisci i dati dei tornei con il dataset mondiale
world = world.merge(tornei_unici_per_paese, how='left', left_on=['NAME'], right_on=['Country'])

# Imposta il valore 0 per i paesi senza tornei
world['Numero_Tornei'] = world['Numero_Tornei'].fillna(0)

# Crea la figura con dimensioni personalizzate
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Crea la mappa
world.plot(column='Numero_Tornei', 
          ax=ax,
          legend=True,
          legend_kwds={'label': 'Numero di Tornei ATP per Paese'},
          missing_kwds={'color': 'lightgrey'},
          cmap='YlOrRd')

# Personalizza il layout
plt.title('Distribuzione Mondiale dei Tornei ATP)', fontsize=16, pad=20)
plt.axis('off')

# Mostra la mappa
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Carica il dataset mondiale
world = gpd.read_file('110m_cultural/ne_110m_admin_0_countries.shp')

# Stampa le colonne disponibili nel dataset world
print("Colonne disponibili nel dataset world:")
print(world.columns)

# Prepara i dati dei tornei
tornei_per_paese = df['Country'].value_counts().reset_index()
tornei_per_paese.columns = ['Country', 'Numero_Tornei']

# Unisci i dati usando 'SOVEREIGNT' o 'NAME' o 'ADMIN' (scegli quello appropriato)
world = world.merge(tornei_per_paese, how='left', left_on=['ADMIN'], right_on=['Country'])
world['Numero_Tornei'] = world['Numero_Tornei'].fillna(0)

# Crea bins personalizzati per la legenda
bins = [0, 1, 5, 10, 20, 50, 100, world['Numero_Tornei'].max()]
world['Tornei_Categoria'] = pd.cut(world['Numero_Tornei'], 
                                 bins=bins, 
                                 labels=[f'{bins[i]}-{bins[i+1]}' for i in range(len(bins)-1)])

# Imposta lo stile della mappa
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Crea la mappa con stile personalizzato
world.plot(column='Numero_Tornei',
          ax=ax,
          legend=True,
          legend_kwds={'label': 'Numero di Tornei ATP',
                      'orientation': 'horizontal',
                      'shrink': 0.8},
          missing_kwds={'color': 'lightgrey'},
          cmap='YlOrRd')

# Aggiungi titolo e personalizzazioni
plt.title('Distribuzione Mondiale dei Tornei ATP\n', 
         fontsize=16, 
         pad=20)

# Rimuovi assi
ax.axis('off')

# Aggiungi una griglia di riferimento
ax.grid(True, linestyle='--', alpha=0.7)

# Aggiungi annotazioni per i paesi con più tornei
for idx, row in world[world['Numero_Tornei'] > 20].iterrows():
    ax.annotate(row['ADMIN'],  # Usa 'ADMIN' invece di 'name'
                xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                xytext=(3, 3),
                textcoords="offset points",
                fontsize=8,
                color='darkblue')

plt.tight_layout()
plt.show()
# Out:
# Colonne disponibili nel dataset world:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=169)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Carica il dataset mondiale
world = gpd.read_file('110m_cultural/ne_110m_admin_0_countries.shp')

# Prepara i dati dei tornei
tornei_per_paese = df['Country'].value_counts().reset_index()
tornei_per_paese.columns = ['Country', 'Numero_Tornei']

# Unisci i dati usando 'ADMIN'
world = world.merge(tornei_per_paese, how='left', left_on=['ADMIN'], right_on=['Country'])
world['Numero_Tornei'] = world['Numero_Tornei'].fillna(0)

# Crea bins personalizzati per la legenda
bins = [0, 1, 5, 10, 20, 50, 100, world['Numero_Tornei'].max()]
world['Tornei_Categoria'] = pd.cut(world['Numero_Tornei'], 
                                   bins=bins, 
                                   labels=[f'{bins[i]}-{bins[i+1]}' for i in range(len(bins)-1)])

# Imposta lo stile della mappa
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Crea la mappa con stile personalizzato
world.boundary.plot(ax=ax, linewidth=1, color='black')  # Aggiungi contorni ai paesi
world.plot(column='Numero_Tornei',
           ax=ax,
           legend=True,
           legend_kwds={'label': 'Numero di Tornei ATP',
                        'orientation': 'horizontal',
                        'shrink': 0.8},
           missing_kwds={'color': 'lightgrey'},
           cmap='YlOrRd')

# Aggiungi titolo e personalizzazioni
plt.title('Distribuzione Mondiale dei Tornei ATP\n(Conteggio Tornei per Paese)', 
          fontsize=16, 
          pad=20)

# Rimuovi assi
ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Carica il file CSV
df = pd.read_csv('atp_tennis.csv')

# Carica il dataset mondiale
world = gpd.read_file('110m_cultural/ne_110m_admin_0_countries.shp')

# Calcola il numero di tornei unici per ciascun paese
tornei_unici_per_paese = df.groupby('Country')['Tournament'].nunique().reset_index()
tornei_unici_per_paese.columns = ['Country', 'Numero_Tornei']

# Unisci i dati usando 'ADMIN'
world = world.merge(tornei_unici_per_paese, how='left', left_on=['ADMIN'], right_on=['Country'])
world['Numero_Tornei'] = world['Numero_Tornei'].fillna(0)

# Assicurati che il massimo valore di Numero_Tornei sia maggiore di tutti i valori nei bin
max_tornei = world['Numero_Tornei'].max()
bins = [0, 1, 5, 10, 20, max_tornei + 1]  # Aggiungi 1 per garantire che il massimo sia incluso

# Crea bins personalizzati per la legenda
world['Tornei_Categoria'] = pd.cut(world['Numero_Tornei'], 
                                   bins=bins, 
                                   labels=[f'{bins[i]}-{bins[i+1]}' for i in range(len(bins)-1)])

# Imposta lo stile della mappa
fig, ax = plt.subplots(1, 1, figsize=(20, 10))

# Crea la mappa con stile personalizzato
world.boundary.plot(ax=ax, linewidth=1, color='black')  # Aggiungi contorni ai paesi
world.plot(column='Numero_Tornei',
           ax=ax,
           legend=True,
           legend_kwds={'label': 'Numero di Tornei ATP Unici per Paese',
                        'orientation': 'horizontal',
                        'shrink': 0.8},
           missing_kwds={'color': 'lightgrey'},
           cmap='viridis')  # Cambia la scala di colori a 'viridis'

# Aggiungi titolo e personalizzazioni
plt.title('Distribuzione Mondiale dei Tornei ATP Unici\n(Conteggio Tornei per Paese)', 
          fontsize=16, 
          pad=20)

# Rimuovi assi
ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Calcola il numero di vittorie per ciascun giocatore
vittorie_giocatori = df['Winner'].value_counts()

# Visualizza i primi 10 giocatori per numero di vittorie
vittorie_giocatori.head(10).plot(kind='bar', color='green')
plt.title('Top 10 Giocatori per Numero di Vittorie')
plt.xlabel('Giocatore')
plt.ylabel('Vittorie')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtra i dati per un giocatore specifico
player_name = 'Federer R.'
player_data = df[df['Winner'] == player_name]

# Converte le date in formato datetime
player_data['Date'] = pd.to_datetime(player_data['Date'])

# Conta le vittorie per anno
vittorie_annuali = player_data.groupby(player_data['Date'].dt.year).size()

# Grafico a linee
vittorie_annuali.plot(kind='line', marker='o')
plt.title(f'Andamento delle Vittorie di {player_name} nel Tempo')
plt.xlabel('Anno')
plt.ylabel('Numero di Vittorie')
plt.show()
# Out:
# /var/folders/zt/9ggmn83106zfjymwl_r2kkdh0000gn/T/ipykernel_61251/801867387.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_data['Date'] = pd.to_datetime(player_data['Date'])
